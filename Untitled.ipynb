# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# annotated-doc                      0.0.4
# annotated-types                    0.7.0
# anyio                              4.13.0
# appnope                            0.1.4
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               25.1.0
# arrow                              1.4.0
# asttokens                          3.0.1
# async-lru                          2.3.0
# attrs                              26.1.0
# azure-core                         1.41.0
# azure-cosmos                       4.3.1
# azure-storage-blob                 12.30.0
# azure-storage-file-datalake        12.25.0
# babel                              2.18.0
# beautifulsoup4                     4.15.0
# black                              26.5.1
# bleach                             6.4.0
# blinker                            1.9.0
# boto3                              1.43.26
# ...

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# annotated-doc                      0.0.4
# annotated-types                    0.7.0
# anyio                              4.13.0
# appnope                            0.1.4
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               25.1.0
# arrow                              1.4.0
# asttokens                          3.0.1
# async-lru                          2.3.0
# attrs                              26.1.0
# azure-core                         1.41.0
# azure-cosmos                       4.3.1
# azure-storage-blob                 12.30.0
# azure-storage-file-datalake        12.25.0
# babel                              2.18.0
# beautifulsoup4                     4.15.0
# black                              26.5.1
# bleach                             6.4.0
# blinker                            1.9.0
# boto3                              1.43.26
# ...

# %%
pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#
# [notice] A new release of pip is available: 25.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/premkumargontrand/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %% [markdown]
# NLP: NLTK,spacy, genism  legacy product
# textBlob -- 2013/14 -- production ( bank ) chatbot -- rules  - user id/ problem , ticket , some will get back to you
# Neural network - tensorflow, pytorch, keras
# Data engineering -
# Data lableling company -- tagging/ label -  consolidation of the data /unwanted information - html, xml, special character/ labelling - meaning, content,topics, image-  content, topic, information
#
# 50,000 - Data labelling  - wipro - 750 / taiwan - 30,000 - openai, google, grok
#
# tokenization :  word tokenization , sentence tokenization
# i am learning python -- i, am, learning, python -- word tokenization
# dividing the sentence by fullstop we call that as sentence tokenization
#
# stop word/filler word  - word which will not have any meaning when used individually -- a, an, and, or , not, why, when, at.
#
# learning, python --
#
# stemming /lemmatization -
# Stemming - without understanding the meaning of the word and it divided the word to identify the root word
#
# learning == learn + ing
# python  == pyth + on
#
# lemmatization : after understanding the meaning of the word and then it divided the word to identify the root word
# learning == learn + ing
# python == python
#
# google search, gpt query
# i want to learn python --
#
# Google search
# plain search by grouping the word
#
# want  + learn + python  --
# want + learn
# learn + python
# want
# learn
# python
#
# gpt query
# i am learn ing python - 5 token --  input token /output token
# want  learn python ( open end question )
#
# learn python -- > want - context search
#
#  learn python --
#  1 blogs
#  2 book
#  3 link
#  4  paper
# ranking of the information
# consolidation of the data
# summarization
#
# output
